# %% [markdown]
# # Tutorial 1: **Notebook** - *FVF*
#
# **By
# gLayout Team**
#
# __Content creators:__ Subham Pal, Saptarshi Ghosh
#
# __Content reviewers:__ Mehedi Saligne

# %% [markdown]
# ___
# # Tutorial Objectives
#
# This notebook is a tutorial on-
#
# - **Importing** and **Placement** of FETs and other macros/Pcells with relative coordinates + Placing (and connecting) Via_stack on the ports of the FETs + encircling them with padrings.
# - **Routing** between the placed *Vias* with *C_*, *L_*, *Straight_* and *smart* Routes and explaining the differences between these strategies. Particularly explaning the East/West/North/South angles, (For Example, why C has to parallel but L has to be perpendicular sides) and *Placing and connecting PINs for future LVS runs

# %% [markdown]
# ## **Target** **Block** : **Flipped Voltage Follwer Cell**
#
# A **voltage follower**—also known as a unity-gain buffer or buffer amplifier—is an electronic circuit in which the output voltage precisely follows the input voltage, providing a voltage gain of one. Typically implemented using an operational amplifier (op-amp) with negative feedback, the voltage follower features extremely high input impedance and very low output impedance. This configuration allows it to isolate circuit stages, preventing the loading of the input source and enabling the circuit to drive low-impedance loads without signal degradation.
#
# The voltage follower is fundamental in analog circuit design, ensuring signal fidelity and stability across a wide range of electronic applications. The **Flipped Voltage Follower (FVF)** is an advanced analog circuit topology derived from the conventional source follower, optimized for low-voltage, low-power applications. Unlike the standard voltage follower, the FVF employs a feedback structure that forces the input transistor to operate at a constant drain current, independent of variations in input voltage or load current. This is achieved using shunt negative feedback and ancillary biasing circuitry, resulting in improved linearity and significantly reduced output impedance compared to traditional designs.
#
# **Key Features:**
# - **Low Output Impedance:** The FVF provides much lower output impedance than conventional voltage followers, making it highly effective as a voltage buffer in demanding analog applications[9][11].
# - **High Linearity:** Maintains a consistent voltage transfer characteristic across a wide range of operating conditions[5][9].
# - **Large Output Current Capability:** Able to source or sink larger currents, supporting class-AB operation and driving heavier loads[4][7][10].
# - **Low-Voltage Operation:** Well-suited for modern low-supply-voltage and low-power integrated circuit designs[4][5][7][10].
# - **Applications:** Commonly found in output stages, current mirrors, voltage buffers, gain-boosting circuits, OTAs, filters, and VCOs[4][5][7][10][11].
#
# The FVF is a versatile and robust building block in analog and mixed-signal circuit design, offering superior performance for buffering, level shifting, and driving loads in advanced CMOS technologies.
#
# (a) Conventional Voltage follower (common Drain); (b) Flipped voltage follower (FVF).
#
# ![](_images/FVF.png)
#
# ```bibtex
# Domala, N., Sasikala, G. Low power flipped voltage follower current mirror with improved input output impedances. Sādhanā 46, 142 (2021). https://doi.org/10.1007/s12046-021-01665-6
# ```

# %% [markdown]
# ## **Layout generation**
# let's go through the step by step procedure to generate LVS and DRC clean layout of a FVF cell.
#
#
# ### *Creating environment for live GDSII viewer*
# You can see the generated GDSII file immediately inside this notebook. You can also view it in Klayout for better understanding. Code for viewing it in Klayout is added but commented out.

# %%
## Activate if necessary to install following packages

# !pip install svgutils
# !pip install ipywidgets

# %% [markdown]
# This cell only required for [IIC-OSIC Docker](https://github.com/iic-jku/IIC-OSIC-TOOLS). It imports all neceaasry environment varriable to current session

# %%
# Environment bootstrap — works in both iic-osic-tools and bare-venv setups.
# iic-osic-tools defines PDK_ROOT / PDK / PDKPATH in ~/.bashrc but jupyter
# kernels launched from its menu don't inherit them, so we re-source bashrc.
# setdefault() means we never overwrite variables already exported by the
# caller. In bare-venv setups, PDKPATH is derived from PDK_ROOT/PDK if not
# already set. See tutorial/HOW_TO_RUN.md for the env-var contract.
import os
import subprocess
try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    pass
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))

# %%
import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirect all outputs here
hide = widgets.Output()

def display_gds(gds_file,path,scale = 3):
  
  # Generate an SVG image
  top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
  top_level_cell.write_svg(os.path.join(path,'out.svg'))
    
  # Scale the image for displaying
  fig = sg.fromfile(os.path.join(path,'out.svg'))
  fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
  fig.save(os.path.join(path,'out.svg'))

  # Display the image
  IPython.display.display(IPython.display.SVG(os.path.join(path,'out.svg')))
  os.remove(os.path.join(path,'out.gds'))

def display_component(component,path,scale = 3):
  # Save to a GDS file
  with hide:
    component.write_gds(os.path.join(path,'out.gds'))
  display_gds(os.path.join(path,'out.gds'),path,scale)

# %%
from glayout import MappedPDK, sky130 , gf180
#from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle
# Out:
# /foss/designs/gLayout/src/glayout/spice/netlist.py:128: SyntaxWarning: invalid escape sequence '\d'
#   if re.match("^wire[\d]+$", self.netlist_connections[net1_index][node1_index]):
# /foss/designs/gLayout/src/glayout/spice/netlist.py:131: SyntaxWarning: invalid escape sequence '\d'
#   elif re.match("^wire[\d]+$", self.netlist_connections[net2_index][node2_index]):

# %%
from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring

# %%
from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist

# %%
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route

# %% [markdown]
# FVF has two fets as shown in the schematic. We call M1 as input fet and M2 as feedback fet. Lets define arguments for the FETs

# %%
nmos_kwargs = {
    "with_tie": True,
    "with_dnwell": True,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": True
}

pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": True
}

# %% [markdown]
# There is no need to manually define the kwargs for your code. This is only done for this notebook implementation.
#
#
# Now, Let's create a list for parameters which we need for our function-
#
# * pdk: pdk to use
# * device_type: either "nmos" or "pmos"
# * placement: either "horizontal" or "vertical"
# * width: (input fet, feedback fet)
# * length: (input fet, feedback fet)
# * fingers: (input fet, feedback fet)
# * multipliers: (input fet, feedback fet)
# * dummy_1: dummy for input fet
# * dummy_2: dummy for feedback fet
# * tie_layers1: tie layers for input fet
# * tie_layers2: tie layers for feedback fet
# * sd_rmult: sd_rmult for both fets

# %%
flipped_voltage_follower_config={
        "pdk": gf180, # pdk to use
        "device_type": "nmos", # either nmos or pmos
        "placement" : "horizontal", # the two fets can be placed either vertically or horizontally
        "width": (3,3), # width of the input fet and feedback fet respectively.
        "length": (None,None), # length of the input fet and feedback fet respectively. None refers to the min length in the pdk.
        "fingers": (1,1), # no. of fingers of the input fet and feedback fet respectively.
        "multipliers": (1,1), #no. of multipliers of the input fet and feedback fet respectively.
        "dummy_1": (True,True), # dummy pattern for input fet (left,right)
        "dummy_2": (True,True), # dummy pattern for the feedback fet (left,right)
        "tie_layers1": ("met2","met1"), #tapring metal layers for input fet
        "tie_layers2": ("met2","met1"), #tapring metal layers for feedback fet
        "sd_rmult":1, # thickness of the sd metal layer.
}

# %% [markdown]
# ### First: We create a top level component and add a name

# %%
top_level = Component(name="flipped_voltage_follower")

# %% [markdown]
# ### Two fets
#
# For our fvf block, we do not want deep nwell. However nmos and pmos primitives have different parameter name for deepnwell.
# For pmos it is set to false by default.We need to set it to false if the device type is given as nmos.
# We could've just set it properly in our nmos_kwargs,
# but since you will probably not code the layout for a notebook, we show a general way of solving this issue.

# %%
device_type = flipped_voltage_follower_config["device_type"]
device_map = {
        "nmos": nmos,
        "pmos":pmos,
        }

device = device_map.get(device_type)
if device_type == "nmos":
      nmos_kwargs["with_dnwell"] = False

# %%
pdk=flipped_voltage_follower_config["pdk"]
pdk.activate()
# Out:
# 2026-06-11 05:27:16.504 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
width=flipped_voltage_follower_config["width"]
length=flipped_voltage_follower_config["length"]
fingers=flipped_voltage_follower_config["fingers"]
multipliers=flipped_voltage_follower_config["multipliers"]

dummy_1=flipped_voltage_follower_config["dummy_1"]
dummy_2=flipped_voltage_follower_config["dummy_2"]
tie_layers1=flipped_voltage_follower_config["tie_layers1"]
tie_layers2=flipped_voltage_follower_config["tie_layers2"]
sd_rmult=flipped_voltage_follower_config["sd_rmult"]

# %%
#fet_1 is the input fet
fet_1 = device(pdk, width=width[0], fingers=fingers[0], multipliers=multipliers[0], with_dummy=dummy_1, with_substrate_tap=False, length=length[0], tie_layers=tie_layers1, sd_rmult=sd_rmult, **(nmos_kwargs if device_type == "nmos" else pmos_kwargs))
#fet_2 is the feedback fet
fet_2 = device(pdk, width=width[1], fingers=fingers[1], multipliers=multipliers[1], with_dummy=dummy_2, with_substrate_tap=False, length=length[1], tie_layers=tie_layers2, sd_rmult=sd_rmult, **(nmos_kwargs if device_type == "nmos" else pmos_kwargs))
well = "pwell" if device == nmos else "nwell"

# %% [markdown]
# Adding the references of the FETs to the top level component

# %%
fet_1_ref = top_level << fet_1
fet_2_ref = top_level << fet_2

fet_1_ref.name = "fet1_ref"
fet_2_ref.name = "fet2_ref"

#let's take a look at our current state of layout
## To see in Klayout via Klive
# top_level.show()
display_component(top_level, scale = 5,path="./")
## If you want to save the gds file at this stage
primary_gds = top_level.write_gds("before_placement.gds")
# Out:
# /tmp/ipykernel_9218/902286224.py:12: UserWarning: Unnamed cells, 2 in 'flipped_voltage_follower'
#   primary_gds = top_level.write_gds("before_placement.gds")
# 2026-06-11 05:27:20.090 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to 'before_placement.gds'

# %% [markdown]
# ### Placement
#
# When a cell is referenced to the top level, the center of the cell is aligned to the (0,0) co-ordinate.
# As of now, both of our fets are centered at (0,0). We need place them properly depending on the placement parameter.

# %%
placement=flipped_voltage_follower_config["placement"]
ref_dimensions = evaluate_bbox(fet_2)

# %% [markdown]
# evaluate_bbox returns maximum width and maximum height of the block as a tuple(width,height).
#
# So here we have `ref_dimensions=(x-dimension of fet_2, y-dimension of fet_2)`
#
# For horizontal placement , we need to move the fet_2 in rightward direction.
# We use the movex function, which moves the center of the block in x-directon upto a certain distance. We need to find out this distance.
# Remember that both fet_1 and fet_2 are centered at (0,0) co-ordinate right now.
# At first we move the center of fet_2 to rightmost point of fet_1 using the xmax function, i.e, (fet_1_ref.xmax,0).
# Now we will find that left half of fet_2 is overlapping with fet_1, so we need to move it at rightward direction again.We move it by ref_dimensionsp[0]/2 distance.
# Now we see that the rightmost point of fet_1 and leftmost point of fet_2 have no seperation between them.
# This will cause a drc error. So we move it again by max seperation needed between two metal layers for drc free layout.
# We move it by 1um again for leaving some routing space for future use.
#
# Vertical placement can be done in similar way by using movey function.

# %%
if placement == "horizontal":
    fet_2_ref.movex(fet_1_ref.xmax)
    display_component(top_level, scale = 2,path="./")
    fet_2_ref.movex(ref_dimensions[0]/2)
    display_component(top_level, scale = 2,path="./")
    fet_2_ref.movex(pdk.util_max_metal_seperation()+1)
elif placement == "vertical":
    display_component(top_level, scale = 2,path="./")
    fet_2_ref.movey(fet_1_ref.ymin - ref_dimensions[1]/2 - pdk.util_max_metal_seperation()-1)
else:
    raise ValueError("Placement must be either 'horizontal' or 'vertical'.")
# let's see how our block looks after placement
display_component(top_level, scale = 2,path="./")
## To see in Klayout via Klive
#top_level.show()
primary_gds = top_level.write_gds("after_placement.gds")
# Out:
# /tmp/ipykernel_9218/1699457151.py:16: UserWarning: Unnamed cells, 2 in 'flipped_voltage_follower'
#   primary_gds = top_level.write_gds("after_placement.gds")
# 2026-06-11 05:27:20.592 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to 'after_placement.gds'

# %% [markdown]
#  ### Routing
#
# Now that our fets are properly placed, we need to make proper connections between ports (i.e. Gates, Sources and Drains of the FETs).
# Each port has four directions- East,North,West,South which means 0,90,180,270 degrees respectively.
# You can connect directly to a fet port. For better felxibility in routing, we choose add some intermediate vias here.
#
# ![](_images/port_route.png)

# %%
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.

#we need four such vias
drain_1_via = top_level << viam2m3
source_1_via = top_level << viam2m3
gate_1_via = top_level << viam2m3

drain_2_via = top_level << viam2m3
gate_2_via = top_level << viam2m3

# %% [markdown]
# The move function moves the center of a specific cell to a specific co-ordinate.
# The co-ordinates of the center of a port can be accesed by using cell_name.ports["port_name"].center
# Using these two and other techniques previously discussed, we properly place these 4 vias.

# %%
drain_1_via.move(fet_1_ref.ports["multiplier_0_drain_W"].center).movex(-0.5*evaluate_bbox(fet_1)[1])
source_1_via.move(fet_1_ref.ports["multiplier_0_source_E"].center).movex(1.5)
gate_1_via.move(fet_1_ref.ports["multiplier_0_gate_E"].center)

drain_2_via.move(fet_2_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)
gate_2_via.move(fet_2_ref.ports["multiplier_0_gate_E"].center).movex(1)

# let's see where those vias are now
## To see in Klayout via Klive
#top_level.show()
display_component(top_level, scale = 3,path="./")
primary_gds = top_level.write_gds("after_vias.gds")
# Out:
# /tmp/ipykernel_9218/4051744565.py:12: UserWarning: Unnamed cells, 2 in 'flipped_voltage_follower'
#   primary_gds = top_level.write_gds("after_vias.gds")
# 2026-06-11 05:27:20.983 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to 'after_vias.gds'

# %% [markdown]
# Now that the vias are placed, time to make metal routing.
# There are three basic types of routing available:
#
# - `straight_route` - the ports must be straight to each other, i.e, opposite direction and same x or y coordinate.
# - `L_route` - has a 90&deg; bend, ports must be perpendicular to each other.
# - `c_route` -  has two 90&deg; bends(c shaped), ports must have same direction.
#
# Each routing function has multiple parameters. See [here](https://github.com/idea-fasoc/OpenFASOC/tree/main/openfasoc/generators/glayout/glayout/flow/routing)
#
# ![](_images/route_direction.png)

# %% [markdown]
# Bonus: You can see all avaliable ports by `top_level.pprint_ports()`

# %% [markdown]
# From the schematic, we see that we need to connect these two nodes-
#
# 1. Source of M1 and Drain of M2, we insert two intermediate vias near each of them and connect them.
# 2. Gate of M2 and Drain of M1, we insert two intermediate vias near each of them and connect them.

# %%
top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_source_E"], source_1_via.ports["bottom_met_W"])
top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_gate_S"], gate_1_via.ports["bottom_met_N"])
top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_drain_W"], drain_2_via.ports["bottom_met_E"])
top_level << c_route(pdk, source_1_via.ports["top_met_N"], drain_2_via.ports["top_met_N"], extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_drain_W"], drain_1_via.ports["bottom_met_E"])
top_level << c_route(pdk, drain_1_via.ports["top_met_S"], gate_2_via.ports["top_met_S"], extension=1.2*max(width[0],width[1]), cglayer="met2")
top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_gate_E"], gate_2_via.ports["bottom_met_W"])
try:
    top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_source_W"], fet_2_ref.ports["tie_W_top_met_W"], glayer1=tie_layers2[1], fullbottom=True)
except:
    pass

# let's see how those vias are now routed
#top_level.show()
display_component(top_level, scale = 3,path="./")
primary_gds = top_level.write_gds("after_routing.gds")
# Out:
# /tmp/ipykernel_9218/1321263656.py:16: UserWarning: Unnamed cells, 2 in 'flipped_voltage_follower'
#   primary_gds = top_level.write_gds("after_routing.gds")
# 2026-06-11 05:27:21.769 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to 'after_routing.gds'

# %% [markdown]
# Notice how in the above lines, ports used in straight routing has the opposite direction, e.g. (E,W) but ports used in c_route has the same direction (N,N).

# %% [markdown]
# ### Renaming Ports
#
# We need to rename ports and add them to the top level component for ease of routing in hierarchial design.
# Here we rename ports by adding appropriate prefix to the all ready existing port names.

# %%
top_level.add_ports(fet_1_ref.get_ports_list(), prefix="A_")
top_level.add_ports(fet_2_ref.get_ports_list(), prefix="B_")
top_level.add_ports(drain_1_via.get_ports_list(), prefix="A_drain_")
top_level.add_ports(source_1_via.get_ports_list(), prefix="A_source_")
top_level.add_ports(gate_1_via.get_ports_list(), prefix="A_gate_")
top_level.add_ports(drain_2_via.get_ports_list(), prefix="B_drain_")
top_level.add_ports(gate_2_via.get_ports_list(), prefix="B_gate_")

# %% [markdown]
# ### Add nwell
#
# for pmos device type, we need to add nwell.
# However we do not need to add pwell for nmos device type as magic does not seperately extract the pwell layer.

# %%
if well == "nwell":
    top_level.add_padding(layers=(pdk.get_glayer("nwell"),),default= 1 )

# %% [markdown]
# ## Add tapring

# %%
shift_amount = -prec_center(top_level.flatten())[0];
tap_ring = tapring(pdk, enclosed_rectangle=evaluate_bbox(top_level.flatten(), padding=pdk.get_grule("nwell")['min_separation']));
tring_ref = top_level << tap_ring;
tring_ref.movex(destination=shift_amount);

# %%
component = component_snap_to_grid(rename_ports_by_orientation(top_level))

# Now that our block is complete, let's see how it looks now!!
#component.show()
display_component(component, scale = 2,path="./")
#component.show()
##fvf_gds = component.write_gds("fvf.gds")

# %% [markdown]
# Printing List of Ports of the Component

# %%
## To see all Ports
# component.pprint_ports()

## To see selected ports
# for s in component.get_ports_list():
#     if len(s.name.split("_")) <4:
#         if set(["A","gate"]).issubset(set(s.name.split("_"))):
#             print(s.name, s.port_type , s.orientation, s.center, s.width, s.layer)

# %% [markdown]
# ### Add Pins
# We need to add i/o pins, power supply pins and bias pins to a circuit. This will be needed later to do LVS check(Layout Vs Schematic) and parasitic extraction(PEX).
# Our flipped voltage follwer has four pins- VIN, VOUT, Ib, VBULK

# %%
psize=(0.5,0.5)
# list that will contain all port/comp info
move_info = list()
# create labels and append to info list

# %%
# gnd
gndlabel = rectangle(layer=pdk.get_glayer("met2_pin"),size=psize,centered=True).copy()
gndlabel.add_label(text="VBULK",layer=pdk.get_glayer("met2_label"))
move_info.append((gndlabel,component.ports["B_tie_N_top_met_N"],None))
#gnd_ref = top_level << gndlabel;



#currentbias
ibiaslabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
ibiaslabel.add_label(text="Ib",layer=pdk.get_glayer("met3_pin"))
move_info.append((ibiaslabel,component.ports["A_drain_top_met_N"],None))
#ib_ref = top_level << ibiaslabel;


# output
outputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
outputlabel.add_label(text="VOUT",layer=pdk.get_glayer("met3_pin"))
move_info.append((outputlabel,component.ports["A_source_top_met_N"],None))
#op_ref = top_level << outputlabel;


# input
inputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
inputlabel.add_label(text="VIN",layer=pdk.get_glayer("met3_pin"))
move_info.append((inputlabel,component.ports["A_gate_top_met_N"], None))
#ip_ref = top_level << inputlabel;


for comp, prt, alignment in move_info:
        alignment = ('c','b') if alignment is None else alignment
        compref = align_comp_to_port(comp, prt, alignment=alignment)
        top_level.add(compref)
component = top_level.flatten()


#component.show()
display_component(top_level, scale =5,path="./")

# %% [markdown]
# ## Note
# Now, lets construct the Pcell and export this code as a `.py` file. This is how your cell contributions should be structured.

# %%
fvf_code_string = """
from glayout import MappedPDK, sky130 , gf180
# from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle

from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring

from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist

from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route


# Environment bootstrap — both iic-osic-tools and bare-venv. See HOW_TO_RUN.md.
import os
import subprocess
try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    pass
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))


def add_fvf_labels(
    fvf_in: Component,
    pdk: MappedPDK,
    ) -> Component:
    fvf_in.unlock()

    psize=(0.5,0.5)
    # list that will contain all port/comp info
    move_info = list()
    # create labels and append to info list

    # gnd
    gndlabel = rectangle(layer=pdk.get_glayer("met2_pin"),size=psize,centered=True).copy()
    gndlabel.add_label(text="VBULK",layer=pdk.get_glayer("met2_label"))
    move_info.append((gndlabel,fvf_in.ports["B_tie_N_top_met_N"],None))
    #gnd_ref = top_level << gndlabel;
    
    
    
    #currentbias
    ibiaslabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    ibiaslabel.add_label(text="Ib",layer=pdk.get_glayer("met3_pin"))
    move_info.append((ibiaslabel,fvf_in.ports["A_drain_top_met_N"],None))
    #ib_ref = top_level << ibiaslabel;
    
    
    # output
    outputlabel = rectangle(layer=pdk.get_glayer("met3_pin"),size=psize,centered=True).copy()
    outputlabel.add_label(text="VOUT",layer=pdk.get_glayer("met3_pin"))
    move_info.append((outputlabel,fvf_in.ports["A_source_top_met_N"],None))
    #op_ref = top_level << outputlabel;
    
    
    # input
    inputlabel = rectangle(layer=pdk.get_glayer("met2_pin"),size=psize,centered=True).copy()
    inputlabel.add_label(text="VIN",layer=pdk.get_glayer("met2_pin"))
    move_info.append((inputlabel,fvf_in.ports["A_gate_top_met_N"], None))
    #ip_ref = top_level << inputlabel;
    
    
    # move everything to position
    for comp, prt, alignment in move_info:
        alignment = ('c','b') if alignment is None else alignment
        compref = align_comp_to_port(comp, prt, alignment=alignment)
        fvf_in.add(compref)
        
    return fvf_in.flatten() 

# @cell
def  flipped_voltage_follower(
        pdk: MappedPDK,
        device_type: str = "nmos", 
        placement: str = "horizontal",
        width: tuple[float,float] = (3,3),
        length: tuple[float,float] = (None,None),
        fingers: tuple[int,int] = (1,1),
        multipliers: tuple[int,int] = (1,1),
        with_substrate_tap: bool = False,
        dummy_1: tuple[bool,bool] = (True,True),
        dummy_2: tuple[bool,bool] = (True,True),
        tie_layers1: tuple[str,str] = ("met2","met1"),
        tie_layers2: tuple[str,str] = ("met2","met1"),
        sd_rmult: int=1,
        **kwargs
        ) -> Component:

    pdk.activate()
    
    #top level component
    top_level = Component(name="flipped_voltage_follower")

    #two fets
    device_map = {
            "nmos": nmos,
            "pmos":pmos,
            }
    device = device_map.get(device_type)
    if device_type == "nmos":
    	kwargs["with_dnwell"] = False  

    fet_1 = device(pdk, width=width[0], fingers=fingers[0], multipliers=multipliers[0], with_dummy=dummy_1, with_substrate_tap=False, length=length[0], tie_layers=tie_layers1, sd_rmult=sd_rmult, **kwargs)
    fet_2 = device(pdk, width=width[1], fingers=fingers[1], multipliers=multipliers[1], with_dummy=dummy_2, with_substrate_tap=False, length=length[1], tie_layers=tie_layers2, sd_rmult=sd_rmult, **kwargs)
    well = "pwell" if device == nmos else "nwell" 
    top_level.info.update({"fet_1": fet_1, "fet_2": fet_2}) #for later access in other functions

    fet_1_ref = top_level << fet_1
    fet_2_ref = top_level << fet_2 
    fet_1_ref.name = "fet1_ref"
    fet_2_ref.name = "fet2_ref"

    #Relative move
    ref_dimensions = evaluate_bbox(fet_2)
    if placement == "horizontal":
        fet_2_ref.movex(fet_1_ref.xmax + ref_dimensions[0]/2 + pdk.util_max_metal_seperation()+1)
    elif placement == "vertical":
        fet_2_ref.movey(fet_1_ref.ymin - ref_dimensions[1]/2 - pdk.util_max_metal_seperation()-1)
        
    else:
        raise ValueError("Placement must be either 'horizontal' or 'vertical'.")
    
    #Routing
    viam2m3 = via_stack(pdk, "met2", "met3", centered=True)
    drain_1_via = top_level << viam2m3
    source_1_via = top_level << viam2m3
    gate_1_via = top_level << viam2m3

    drain_2_via = top_level << viam2m3
    gate_2_via = top_level << viam2m3
    
    drain_1_via.move(fet_1_ref.ports["multiplier_0_drain_W"].center).movex(-0.5*evaluate_bbox(fet_1)[1])
    source_1_via.move(fet_1_ref.ports["multiplier_0_source_E"].center).movex(1.5)
    gate_1_via.move(fet_1_ref.ports["multiplier_0_gate_E"].center)

    drain_2_via.move(fet_2_ref.ports["multiplier_0_drain_W"].center).movex(-1.5)
    gate_2_via.move(fet_2_ref.ports["multiplier_0_gate_E"].center).movex(1)

    top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_source_E"], source_1_via.ports["bottom_met_W"])
    top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_gate_S"], gate_1_via.ports["bottom_met_N"])
    top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_drain_W"], drain_2_via.ports["bottom_met_E"])
    top_level << c_route(pdk, source_1_via.ports["top_met_N"], drain_2_via.ports["top_met_N"], extension=1.2*max(width[0],width[1]), width1=0.32, width2=0.32, cwidth=0.32, e1glayer="met3", e2glayer="met3", cglayer="met2")
    top_level << straight_route(pdk, fet_1_ref.ports["multiplier_0_drain_W"], drain_1_via.ports["bottom_met_E"])
    top_level << c_route(pdk, drain_1_via.ports["top_met_S"], gate_2_via.ports["top_met_S"], extension=1.2*max(width[0],width[1]), cglayer="met2")
    top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_gate_E"], gate_2_via.ports["bottom_met_W"])
    try:
	    top_level << straight_route(pdk, fet_2_ref.ports["multiplier_0_source_W"], fet_2_ref.ports["tie_W_top_met_W"], glayer1=tie_layers2[1], fullbottom=True)
    except:
	    pass
    #Renaming Ports
    top_level.add_ports(fet_1_ref.get_ports_list(), prefix="A_")
    top_level.add_ports(fet_2_ref.get_ports_list(), prefix="B_")
    top_level.add_ports(drain_1_via.get_ports_list(), prefix="A_drain_")
    top_level.add_ports(source_1_via.get_ports_list(), prefix="A_source_")
    top_level.add_ports(gate_1_via.get_ports_list(), prefix="A_gate_")
    top_level.add_ports(drain_2_via.get_ports_list(), prefix="B_drain_")
    top_level.add_ports(gate_2_via.get_ports_list(), prefix="B_gate_")
    #add nwell
    if well == "nwell": 
        top_level.add_padding(layers=(pdk.get_glayer("nwell"),),default= 1 )
    #add tapring
    if with_substrate_tap:
        shift_amount = -prec_center(top_level.flatten())[0];
        tap_ring = tapring(pdk, enclosed_rectangle=evaluate_bbox(top_level.flatten(), padding=pdk.get_grule("nwell")['min_separation']));
        tring_ref = top_level << tap_ring;
        tring_ref.movex(destination=shift_amount);
    
    return component_snap_to_grid(rename_ports_by_orientation(top_level))



if __name__ == "__main__":
\tcomp = flipped_voltage_follower(gf180, device_type='nmos')\n
\t# comp.pprint_ports()\n
\tcomp = add_fvf_labels(comp, gf180)\n
\tcomp.name = "FVF"\n
\tcomp.write_gds('out_FVF.gds')\n
\tcomp.show()\n
\tprint("...Running DRC...")\n
\tdrc_result = gf180.drc_magic(comp, "FVF")\n
\t#drc_result = gf180.drc(comp)\n

"""

fvf_init_string = """
###Glayout FVF Cell.


from .my_FVF import flipped_voltage_follower,add_fvf_labels

__all__ = [
    'flipped_voltage_follower',
    'add_fvf_labels',
] 
"""

directory = "./FVF/"
os.makedirs(directory, exist_ok=True)

# Save to a .py file
with open(directory + "my_FVF.py", "w") as file:
    file.write(fvf_code_string)

with open(directory + "__init__.py", "w") as file:
    file.write(fvf_init_string)

# %% [markdown]
# ### Run DRC with Magic
# Design Rule Check ensures that the physical layout of an integrated circuit adheres to the manufacturing constraints defined by the foundry, such as minimum spacing, width, and enclosure rules. `Magic` is the tool we use for DRC here.

# %%
drc_result = gf180.drc_magic(component, component.name)
# Out:
# 2026-06-11 05:28:38.615 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpyy55l2lp/fvf.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 528 - Compiled on Wed Jun 18 09:45:25 PM CEST 2025.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpyy55l2lp/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "fvf".
# [INFO]: Loading fvf
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmpyy55l2lp/fvf.rpt
#
# Using technology "gf180mcuD", version 1.0.525-0-gf2e289d

# %% [markdown]
# ### DRC Checking Using External Tools (KLayout)
# Design Rule Check (DRC) is the process of ensuring that a particular layout does not violate the constraints or _design rules_ imposed by the PDK.
#
# [Klayout](https://klayout.de/) is a GDSII viewer and editor that also has a DRC feature. The design rules for the PDK, in this case the GF180 PDK, are described in a `.lydrc` file.
#
# The following cell runs DRC on the component generated in the previous cell. The number of DRC errors reported will be displayed at the end of the output.

# %%
drc_result = gf180.drc(component)
# Out:
# 2026-06-11 05:28:44.824 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmptj0rw6_x/fvf.gds'
# KLayout version: 0.30.2
# 2026-06-11 05:28:47 +0200: Memory Usage (666608K) : Starting running GF180MCU Klayout DRC runset on /tmp/tmptj0rw6_x/fvf.gds
# 2026-06-11 05:28:47 +0200: Memory Usage (666608K) : Loading database to memory is complete.
# 2026-06-11 05:28:47 +0200: Memory Usage (666672K) : GF180MCU Klayout DRC runset output at: /foss/designs/notebooks/klayout_drc/gf180_fvf_drcreport.lyrdb
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Number of threads to use 4
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : flat  mode is enabled.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Read in polygons from layers.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Starting deriving base layers.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Evaluate switches.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : FEOL is enabled.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : BEOL is enabled.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : connectivity rules are enabled.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : METAL_TOP Selected is 30K
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : METAL_STACK Selected is 3LM
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Wedge enabled  true
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Ball enabled  true
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Gold enabled  true
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : MIM Option selected A
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Offgrid enabled  true
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Construct connectivity for the design.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Connectivity rules enabled, Netlist object will be generated.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Total area of the design is 443.2296 um^2.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Total no. of polygons in the design is 1239
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Initialization and base layers definition.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Starting GF180MCU DRC rules.
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : FEOL section
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule DN.1
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : CONNECTIVITY_RULES section
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule DN.2a
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule DN.2b
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule DN.3
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.1_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.1_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : CONNECTIVITY_RULES section
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.2a_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.2a_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.2b_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.2b_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.3_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.3_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.5_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.5_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.11
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule LPW.12
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.1a_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.1a_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.1b_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.1b_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : CONNECTIVITY_RULES section
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.2a_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.2a_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.2b_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.2b_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.3_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.3_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.4_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.4_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.5_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.5_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule NW.6
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule DF.1a_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (666672K) : Executing rule DF.1a_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (666960K) : Executing rule DF.1c_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (667248K) : Executing rule DF.1c_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (667540K) : Executing rule DF.2a_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (667832K) : Executing rule DF.2a_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (668124K) : Executing rule DF.2b_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (668268K) : Executing rule DF.2b_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (668412K) : Executing rule DF.3a_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (668560K) : Executing rule DF.3a_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (668560K) : Executing rule DF.3b_3.3V
# 2026-06-11 05:28:48 +0200: Memory Usage (668560K) : Executing rule DF.3b_5V
# 2026-06-11 05:28:48 +0200: Memory Usage (668560K) : Executing rule DF.3c_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.3c_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4a_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4a_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4b_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4b_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4c_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4c_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4d_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4d_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4e_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.4e_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.5_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.5_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.6_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.6_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.7_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.7_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.8_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668560K) : Executing rule DF.8_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (668704K) : Executing rule DF.9_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (668848K) : Executing rule DF.9_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (669140K) : Executing rule DF.10_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (669288K) : Executing rule DF.10_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (669724K) : Executing rule DF.11_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (669868K) : Executing rule DF.11_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (670012K) : Executing rule DF.12_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (670304K) : Executing rule DF.12_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (670740K) : Executing rule DF.13_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (670888K) : Executing rule DF.13_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671176K) : Executing rule DF.14_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DF.14_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DF.16_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DF.16_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DF.17_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DF.17_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DF.18_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DF.18_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DF.19_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DF.19_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DV.1
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DV.2
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DV.3
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DV.5
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DV.6
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DV.7
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DV.8
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule DV.9
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.1_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.1_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.1a_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.1a_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.2_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.2_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.3a_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.3a_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.4_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.4_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.5a_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.5a_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.5b_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.5b_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.6
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.7_3.3V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.7_5V
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.9
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.11
# 2026-06-11 05:28:49 +0200: Memory Usage (671468K) : Executing rule PL.12
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.1
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.2
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.3a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.3bi
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.3bii
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.3ci
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.3cii
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.3d
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.3e
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.4a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.4b
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.5a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.5b
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.5ci
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.5cii
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.5di
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.5dii
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.6
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.7
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.8a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.8b
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.9
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.10
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.11
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule NP.12
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.1
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.2
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.3a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.3bi
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.3bii
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.3ci
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.3cii
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.3d
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.3e
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.4a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.4b
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.5a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.5b
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.5ci
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.5cii
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.5di
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.5dii
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.6
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.7
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.8a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.8b
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.9
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.10
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.11
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule PP.12
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.1
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.2
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.3
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.4
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.5a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.5b
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.6
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.7
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.8
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.9
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.10
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.11
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.12
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.13
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.14a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.14b
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.15a
# 2026-06-11 05:28:50 +0200: Memory Usage (671468K) : Executing rule SB.15b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule SB.16
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.1
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.2
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.3a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.3b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.4a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.4b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.5a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.5b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.6
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.7
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.8
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.pl
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.9
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule ESD.10
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.1
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.2a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.2b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.3
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.4
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.5a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.5b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.6
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.6a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.6b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.7
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.8
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.9
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.10
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule CO.11
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : BEOL section
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M1.1
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M1.2a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M1.2b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M1.3
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M2.1
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M2.2a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M2.2b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M2.3
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M3.1
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M3.2a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M3.2b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M3.3
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M4.1
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M4.2a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M4.2b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M4.3
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M5.1
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M5.2a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M5.2b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule M5.3
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V1.1
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V1.2a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V1.2b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V1.3a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V1.3c
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V1.3d
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V1.4a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V1.4b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V1.4c
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V2.1
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V2.2a
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V2.2b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V2.3b
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V2.3c
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V2.3d
# 2026-06-11 05:28:51 +0200: Memory Usage (671468K) : Executing rule V2.4a
# 2026-06-11 05:28:52 +0200: Memory Usage (671468K) : Executing rule V2.4b
# 2026-06-11 05:28:52 +0200: Memory Usage (671468K) : Executing rule V2.4c
# 2026-06-11 05:28:52 +0200: Memory Usage (671468K) : Executing rule V3.1
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V3.2a
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V3.2b
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V3.3b
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V3.3c
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V3.3d
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V3.4a
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V3.4b
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V3.4c
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V4.1
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V4.2a
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V4.2b
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V4.3b
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V4.3c
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V4.3d
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V4.4a
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V4.4b
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V4.4c
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V5.1
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V5.2a
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V5.2b
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V5.3b
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V5.3c
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V5.3d
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V5.4a
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V5.4b
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule V5.4c
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : MetalTop thickness 30K section
# 2026-06-11 05:28:52 +0200: Memory Usage (671532K) : Executing rule MT30.1a
# 2026-06-11 05:28:52 +0200: Memory Usage (671676K) : Executing rule MT30.1b
# 2026-06-11 05:28:52 +0200: Memory Usage (671968K) : Executing rule MT30.2
# 2026-06-11 05:28:52 +0200: Memory Usage (672112K) : Executing rule MT30.3
# 2026-06-11 05:28:52 +0200: Memory Usage (672324K) : Executing rule MT30.4
# 2026-06-11 05:28:52 +0200: Memory Usage (672324K) : Executing rule MT30.5
# 2026-06-11 05:28:52 +0200: Memory Usage (673116K) : Executing rule MT30.6
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule MT30.8
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule MC.1
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule MC.2
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule MC.3
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule MC.4
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule PRES.1
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule PRES.2
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule PRES.3
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule PRES.4
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule PRES.5
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule PRES.6
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule PRES.7
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule PRES.9a
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule PRES.9b
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule LRES.1
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule LRES.2
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule LRES.3
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule LRES.4
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule LRES.5
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule LRES.6
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule LRES.7
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule LRES.9a
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule LRES.9b
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule HRES.1
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule HRES.2
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule HRES.3
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule HRES.4
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule HRES.5
# 2026-06-11 05:28:52 +0200: Memory Usage (673824K) : Executing rule HRES.6
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule HRES.7
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule HRES.8
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule HRES.9
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule HRES.10
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule HRES.12a
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule HRES.12b
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : MIM Capacitor Option A section
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.1
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.2
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.3
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.4
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.5
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.6
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.7
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.8a
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.8b
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.9
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.10
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule MIM.11
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.1
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.2
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.3
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.4
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.5
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : CONNECTIVITY_RULES section
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.6
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.7
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.8
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.9
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.10
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.11
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule NAT.12
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule BJT.1
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule BJT.2
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule BJT.3
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule DE.2
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule DE.3
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule DE.4
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule LVS_BJT.1
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule O.DF.3a
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule O.DF.6
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule O.DF.9
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule O.PL.2
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule O.PL.3a
# 2026-06-11 05:28:53 +0200: Memory Usage (673824K) : Executing rule O.PL.4
# 2026-06-11 05:28:53 +0200: Memory Usage (673888K) : Executing rule O.SB.2
# 2026-06-11 05:28:53 +0200: Memory Usage (673888K) : Executing rule O.SB.3
# 2026-06-11 05:28:53 +0200: Memory Usage (673952K) : Executing rule O.SB.4
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule O.SB.5b_3.3V
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule O.SB.9
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule O.SB.11
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule O.SB.13_3.3V
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule O.SB.13_5V
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule O.CO.7
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule O.PL.ORT
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.01
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.02
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.03
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.04a
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.04b
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.04c
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.04d
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.05
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.06
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.07
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.08
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.09
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.10
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.11
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.12
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.13
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.14
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.15
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.16a
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.16b
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.17
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.18
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.19
# 2026-06-11 05:28:53 +0200: Memory Usage (674016K) : Executing rule EF.20
# 2026-06-11 05:28:54 +0200: Memory Usage (674016K) : Executing rule EF.21
# 2026-06-11 05:28:54 +0200: Memory Usage (674016K) : Executing rule EF.22a
# 2026-06-11 05:28:54 +0200: Memory Usage (674016K) : Executing rule EF.22b
# 2026-06-11 05:28:54 +0200: Memory Usage (674016K) : Executing rule MDN.1
# 2026-06-11 05:28:54 +0200: Memory Usage (674016K) : CONNECTIVITY_RULES section
# 2026-06-11 05:28:54 +0200: Memory Usage (674016K) : Executing rule MDN.2a
# 2026-06-11 05:28:54 +0200: Memory Usage (674016K) : Executing rule MDN.2b
# 2026-06-11 05:28:54 +0200: Memory Usage (674016K) : Executing rule MDN.3a
# 2026-06-11 05:28:54 +0200: Memory Usage (674016K) : Executing rule MDN.3b
# 2026-06-11 05:28:54 +0200: Memory Usage (674080K) : Executing rule MDN.4a
# 2026-06-11 05:28:54 +0200: Memory Usage (674144K) : Executing rule MDN.4b
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.5ai
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.5aii
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.5b
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.5c
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.6
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.6a
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.7
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.7a
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : CONNECTIVITY_RULES section
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.8a
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.8b
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.9
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.10a
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.10b
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.10c
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.10d
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.10ei
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.10eii
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.10f
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.11
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.12
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.13a
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.13b
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.13c
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.13d
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.14
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.15a
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.15b
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDN.17
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDP.1
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDP.1a
# 2026-06-11 05:28:54 +0200: Memory Usage (674208K) : Executing rule MDP.2
# 2026-06-11 05:28:54 +0200: Memory Usage (674644K) : Executing rule MDP.3
# 2026-06-11 05:28:54 +0200: Memory Usage (675000K) : Executing rule MDP.3ai
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.3aii
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.3b
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.3c
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.3d
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.4
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.4a
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.4b
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.5
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.5a
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.6
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.6a
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.7
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.8
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.9a
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.9b
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.9c
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.9d
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.9ei
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.9eii
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.9f
# 2026-06-11 05:28:54 +0200: Memory Usage (675416K) : Executing rule MDP.10
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : CONNECTIVITY_RULES section
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.10a
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.10b
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.11
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.12
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.13a
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.13b
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.13c
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.15
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.16a
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.16b
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.17a
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule MDP.17c
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule Y.NW.2b_3.3V
# 2026-06-11 05:28:55 +0200: Memory Usage (675416K) : Executing rule Y.NW.2b_5V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.DF.6_5V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.DF.16_3.3V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.DF.16_5V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.PL.1_3.3V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.PL.1_5V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.PL.2_3.3V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.PL.2_5V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.PL.4_5V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.PL.5a_3.3V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.PL.5a_5V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.PL.5b_3.3V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule Y.PL.5b_5V
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.DF.4c_MV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.DF.6_MV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.DF.7_MV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.DF.8_MV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.DF.16_MV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.PL.5a_MV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.PL.5b_MV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.CO.4_MV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.DF.4c_LV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.DF.16_LV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.CO.3_LV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.CO.4_LV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.CO.6_ii_LV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule S.M1.1_LV
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : OFFGRID-ANGLES section
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule comp_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule dnwell_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule nwell_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule lvpwell_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule dualgate_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675480K) : Executing rule poly2_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675608K) : Executing rule nplus_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675672K) : Executing rule pplus_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675736K) : Executing rule sab_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675864K) : Executing rule esd_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675928K) : Executing rule contact_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (675992K) : Executing rule metal1_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676120K) : Executing rule via1_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule metal2_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule via2_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule metal3_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule via3_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule metal4_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule via4_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule metal5_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule via5_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule metaltop_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule pad_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule resistor_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule fhres_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule fusetop_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule fusewindow_d_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule polyfuse_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule mvsd_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule mvpsd_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule nat_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule comp_dummy_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule poly2_dummy_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule metal1_dummy_OFFGRID
# 2026-06-11 05:28:55 +0200: Memory Usage (676184K) : Executing rule metal2_dummy_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676184K) : Executing rule metal3_dummy_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676184K) : Executing rule metal4_dummy_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676184K) : Executing rule metal5_dummy_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676184K) : Executing rule metaltop_dummy_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676184K) : Executing rule comp_label_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676184K) : Executing rule poly2_label_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676184K) : Executing rule metal1_label_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676312K) : Executing rule metal2_label_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676376K) : Executing rule metal3_label_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676504K) : Executing rule metal4_label_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676568K) : Executing rule metal5_label_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676696K) : Executing rule metaltop_label_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676760K) : Executing rule metal1_slot_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676888K) : Executing rule metal2_slot_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (676952K) : Executing rule metal3_slot_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677080K) : Executing rule metal4_slot_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677144K) : Executing rule metal5_slot_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677272K) : Executing rule metaltop_slot_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677336K) : Executing rule ubmpperi_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677464K) : Executing rule ubmparray_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677528K) : Executing rule ubmeplate_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677656K) : Executing rule schottky_diode_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677720K) : Executing rule zener_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677848K) : Executing rule res_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule opc_drc_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule ndmy_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule pmndmy_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule v5_xtor_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule cap_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule mos_cap_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule ind_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule diode_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule drc_bjt_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule lvs_bjt_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule mim_l_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule latchup_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule guard_ring_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule otp_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule mtpmark_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule neo_ee_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule sramcore_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule lvs_rf_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule lvs_drain_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule ind_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule hvpolyrs_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule lvs_io_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule probe_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule esd_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule lvs_source_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule well_diode_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule ldmos_xtor_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule plfuse_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule efuse_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule mcell_feol_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule ymtp_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule dev_wf_mk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule metal1_blk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule metal2_blk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule metal3_blk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule metal4_blk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule metal5_blk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule metalt_blk_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule pr_bndry_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule mdiode_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule metal1_res_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (677912K) : Executing rule metal2_res_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (678040K) : Executing rule metal3_res_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (678104K) : Executing rule metal4_res_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (678104K) : Executing rule metal5_res_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (678104K) : Executing rule metal6_res_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (678104K) : Executing rule border_OFFGRID
# 2026-06-11 05:28:56 +0200: Memory Usage (678104K) : DRC Total Run time 8.893752 seconds
# DRC report saved at: /foss/designs/notebooks/klayout_drc/gf180_fvf_drcreport.lyrdb
# Use Tools -> Marker Browser in KLayout to view the violations.
